# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # $$Question 1.1$$

# %%
#Question 1.1

data = []

with open('sequence_1.txt') as f:
    text = f.read()
    print(text)
# Out:
# >test_sequence_Q1
# ...

# %%
for i in range(len(text)):
    data.append(text[i])

data
# Out:
# ['>',
#  't',
#  'e',
#  's',
#  't',
#  '_',
#  's',
#  'e',
#  'q',
#  'u',
#  'e',
#  'n',
#  'c',
#  'e',
#  '_',
#  'Q',
#  '1',
#  '\n',
#  'A',
#  'A',
#  'C',
#  'C',
#  'C',
#  'C',
#  'T',
#  'A',
#  'T',
#  'G',
#  'T',
#  'C',
#  'T',
#  'A',
#  'A',
#  'G',
#  'A',
#  'T',
#  'G',
#  'A',
#  'C',
#  'G',
#  'C',
#  'T',
#  'G',
#  'T',
#  'G',
#  'G',
#  'C',
#  'C',
#  'T',
#  'A',
#  'A',
#  'G',
#  'G',
#  'G',
#  'G',
#  'T',
#  'G',
#  'G',
#  'C',
#  'A',
#  'A',
#  'C',
#  'C',
#  'G',
#  'G',
#  'A',
#  'A',
#  'T',
#  'A',
#  'C',
#  'T',
#  'G',
#  'G',
#  'G',
#  'C',
#  'T',
#  'C',
#  'G',
#  'C',
#  'A',
#  'T',
#  'C',
#  'T',
#  'G',
#  'C',
#  'C',
#  'G',
#  'A',
#  'G',
#  'G',
#  'T',
#  'C',
#  'A',
#  'G',
#  'C',
#  'T',
#  'G',
#  'A',
#  'C',
#  'C',
#  'C',
#  'G',
#  'G',
#  'A',
#  'G',
#  'C',
#  'G',
#  'T',
#  'T',
#  'C',
#  'A',
#  'T',
#  'T',
#  'T',
#  'A',
#  'G',
#  'T',
#  'A',
#  'G',
#  'G',
#  'T',
#  'A',
#  'T',
#  'C',
# ...

# %%
x = 0

for i in range(len(data)):
    if(data[i]=='A'):
        if(data[i+1]=='G'):
            if(data[i+2]=='A'):
                if(data[i+3]=='T'):
                    if(data[i+4]=='A'):
                        if(data[i+5]=='A'):
                            x+=1

print("There are",x,"AGATAA pairs in this list")
# Out:
# There are 10 AGATAA pairs in this list

# %% [markdown]
# # $$Question 1.2$$

# %%
print('There are',len(data)-18,'values in the given genetic sequence')

#Subtracting 18 because the data loaded in and searched through in the array above, also takes into accound the title.
#The title, is 18 individual characters
# Out:
# There are 2001 values in the given genetic sequence

# %% [markdown]
# # $$Question 1.3$$

# %%
print('The probability of seeing AGATAA in a given sequence is',(1/4)**6)

#1/4 chance to get genes A,T,C, or G. The probability of getting that specific sequence is 
# (1/4)*(1/4)*(1/4)*(1/4)*(1/4)*(1/4)
# Out:
# The probability of seeing AGATAA in a given sequence is 0.000244140625

# %% [markdown]
# # $$Question1.4$$

# %%
AGATAA_prob = (1/4)**6

#10 pairs of AGATAA over 2001 individual genes
print('The average count of AGATAA in this sequence, is', 10/2001)

#Given this mean value of AGATAA from this equation, it can be assumed that for any given gene sequence of this 
#same type, that the average count would be mean value above
# Out:
# The average count of AGATAA in this sequence, is 0.004997501249375313

# %% [markdown]
# # $$Question1.5$$

# %%
#Using Null Hypothesis Testing, we can do the following

H_0 = 10/2001 #Null Hypothesis is that we see 10 AGATAA

H_1 = 11/2001 #Alternative hypothesis is that we see more than ten AGATAA

H_1/2001 #Probability of seeing the sequence using our Alternative Hypothesis
# Out:
# 2.747252061125859e-06

# %% [markdown]
# # $$Question1.6$$

# %% [markdown]
# Yes, I do believe that AGATAA is overrepresented in this data set. The probability of getting one AGATAA sequence alone, is 0.004997501249375313. Finding ten of them in a given sequence, is very VERY extremely unlikely

# %% [markdown]
# # $$Question2.2$$

# %% [markdown]
# The genes I've found in the NCBI ref sequencing region were as follows:
#
# **PKNOX1**
#
# **CBS**
#
# **UTAF1**
#
# **FRGCA**
#
# on the strands:
#
# **NM_001289258.2** PKNOX
#
# **NM_001320694.2** PKNOX
#
# **NM_004571.5** PKNOX
#
# **NM_001321072.1** CBS
#
# **NM_001178008.3** CBS
#
# **NM_001178009.3** CBS
#
# **NM_001320298.2** CBS
#
# **NM_001025204.2** UTAF1
#
# **NM_006758.3** UTAF1
#
# **NM_001025203.1** UTAF1
#
# **NR_133677.1** FRGCA

# %% [markdown]
# # $$Question2.5$$

# %% [markdown]
# No, I don't believe that any peaks were missed. However, I do believe that where some the black bars are in the BED file are not actually peaks (relative to the ones that stand out) and could be considered noise

# %% [markdown]
# # $$Question2.8$$

# %% [markdown]
# Link for my settings; Named "Jimmy192001"

# %% [markdown]
# http://genome.ucsc.edu/cgi-bin/hgTracks?db=hg19&lastVirtModeType=default&lastVirtModeExtraState=&virtModeType=default&virtMode=0&nonVirtPosition=&position=chr21%3A44189390%2D44757808&hgsid=1452424219_cFRv6NsQ0ZK7jFXMb9F5fIdDfrq4
